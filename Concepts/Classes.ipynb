# %%
class MyInt:
    '''Docstring for MyInt'''
    def __init__(self,val):
        self.value = val
        
    def __add__(self,other):
        return MyInt(self.value + other)
    
    def __repr__(self):
        return f'MyInt({self.value})'
    
    def __str__(self):
        return f'{self.value}'
    
    def square(self):
        'Return the square of the value'
        return MyInt(self.value**2)

# %%
MyInt
# Out:
# __main__.MyInt

# %%
num = MyInt(42) # Create an instance of a class
num + 5 #calls .__add__ then __repr__ methods
# Out:
# MyInt(47)

# %%
num - 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-0c71ee5bddc8> in <module>
# ----> 1 num - 5
#
# TypeError: unsupported operand type(s) for -: 'MyInt' and 'int'

# %%
num
# Out:
# MyInt(42)

# %%
num.__add__(4)
# Out:
# MyInt(46)

# %%
MyInt.square??
