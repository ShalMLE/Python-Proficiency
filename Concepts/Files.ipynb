# %%
fout = open('names.csv', mode='w', encoding='utf8')
fout.write('name,age\n')
# Out:
# 9

# %%
fout.write('shal,35\n')
# Out:
# 8

# %%
fout.write('linda,29\n')
# Out:
# 9

# %%
fout.close()

# %%
#with automatically close the file
with open('names.csv', mode='w', encoding='utf8') as fout:
    fout.write('all,70\n')

# %%
help(fout.write)
# Out:
# Help on built-in function write:
#
# write(text, /) method of _io.TextIOWrapper instance
#     Write string to stream.
#     Returns the number of characters written (which is always equal to
#     the length of the string).

# %%
fout.write?

# %%
with open('names.csv', encoding='utf8') as fin:
    data = fin.read()
data
# Out:
# 'all,70\n'

# %%
with open('names.csv', mode='rb') as fin:
    one_byte = fin.read(1)
    ten_bytes = fin.read(10)

# %%
one_byte
# Out:
# b'a'

# %%
ten_bytes
# Out:
# b'll,70\n'

# %%
ten_bytes.decode('utf8')
# Out:
# 'll,70\n'

# %%
with open('uniquereading.txt','w',encoding='utf8') as fout:
    fout.write('Shalini \n(GRINNING FACE)')

# %%
greeting = open('uniquereading.txt','r',encoding='utf8').read()
greeting
# Out:
# 'Shalini \n(GRINNING FACE)'
