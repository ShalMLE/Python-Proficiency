# %% [raw]
# #Defition
# Module - Python File
# Package - Directory with __init__.py file and other packages or modules

# %%
import math
import pandas as pd

# %%
math
# Out:
# <module 'math' from '/Users/sujitprasad/opt/anaconda3/lib/python3.8/lib-dynload/math.cpython-38-darwin.so'>

# %%
pd
# Out:
# <module 'pandas' from '/Users/sujitprasad/opt/anaconda3/lib/python3.8/site-packages/pandas/__init__.py'>

# %%
dir(math)
# Out:
# ['__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc']

# %%
math.sin(0)
# Out:
# 0.0

# %%
df = pd.read_csv('names.csv')

# %%
# %%writefile sample.py
def median(values):
    '''
    Return the middle value (if odd)
    or the average of the two middle values (if even)
    >>>median([1,4,5])
    4
    >>>median([0,2,6,100])
    4.0
    '''
    values = sorted(values)
    size = len(values)
    if size % 2 == 0:
        left = values[int(size/2 - 1)]
        right = values[int(size/2)]
        return (left + right) / 2
    else:
        return values[int(size/2)]
roots2 = lambda val: (val**.5, -(val**.5))
# Out:
# Writing sample.py

# %%
import sample

# %%
sample
# Out:
# <module 'sample' from '/Users/sujitprasad/Documents/Shalini/Python /sample.py'>

# %%
dir(sample)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'median',
#  'roots2']

# %%
sample.median(range(20))
# Out:
# 9.5
